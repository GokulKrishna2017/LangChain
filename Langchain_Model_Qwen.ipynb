# %% [markdown]
# <a href="https://colab.research.google.com/github/GokulKrishna2017/LangChain/blob/main/Langchain_Model_Qwen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qU langchain-huggingface

# %%
import os
from google.colab import userdata
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

# %%
os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get("Modelss")

# %%
llm = HuggingFaceEndpoint(repo_id="Qwen/Qwen2.5-7B-Instruct",
                          task="text-generation",

)

# %%
model = ChatHuggingFace(llm=llm)

# %%
result = model.invoke("what is the capital of ontario and what is the capital of canada?")

# %%
print(result.content)
# Out:
# The capital of Ontario is Toronto. Toronto is located in the eastern part of the province and is the most populous city in Canada.
#
# The capital of Canada is Ottawa. Ottawa is located in the eastern part of the country, in the province of Ontario, and serves as the national capital of Canada.
